# %% [markdown]
# # Analisando as notas em cada área por município do Brasil

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
microdadosEnem = pd.read_csv("microdados_enem_2021/DADOS/MICRODADOS_ENEM_2021.csv", sep=";", encoding='ISO_8859_1')

# %%
microdadosEnem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
#        'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'], dtype=object)

# %%
selecionadas= ['CO_MUNICIPIO_ESC','NO_MUNICIPIO_ESC', 'NU_NOTA_MT','NU_NOTA_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'SG_UF_ESC']

# %%
df=microdadosEnem.filter(items=selecionadas).dropna().groupby('CO_MUNICIPIO_ESC').mean()

# %%
df
# Out:
#                   NU_NOTA_MT  NU_NOTA_REDACAO  NU_NOTA_COMP1  NU_NOTA_COMP2  \
# CO_MUNICIPIO_ESC
# 1100015.0         546.662500       649.000000     118.500000     144.500000
# 1100023.0         518.904422       600.000000     114.285714     135.170068
# 1100031.0         522.883333       470.000000     106.666667     116.666667
# 1100049.0         533.458933       622.506667     117.013333     140.906667
# 1100056.0         480.696875       598.125000     115.000000     134.375000
# ...                      ...              ...            ...            ...
# 5222005.0         516.186486       572.432432     112.972973     137.297297
# 5222054.0         504.085714       554.285714     109.285714     123.571429
# 5222203.0         445.027273       432.727273      78.181818     105.454545
# 5222302.0         460.816667       443.333333      88.888889     114.444444
# 5300108.0         552.325653       633.361890     124.394086     142.195661
#
#                   NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_CN  \
# CO_MUNICIPIO_ESC
# 1100015.0            117.500000     141.500000     127.000000  499.987500
# 1100023.0            112.176871     125.238095     113.129252  475.539456
# 1100031.0             86.666667      93.333333      66.666667  477.266667
# 1100049.0            115.520000     130.026667     119.040000  489.744000
# 1100056.0            115.000000     125.625000     108.125000  479.268750
# ...                         ...            ...            ...         ...
# 5222005.0            110.810811     121.621622      89.729730  449.954054
# 5222054.0            106.428571     120.000000      95.000000  450.285714
# 5222203.0             87.272727      89.090909      72.727273  431.645455
# 5222302.0             96.666667      97.777778      45.555556  432.055556
# 5300108.0            118.428907     131.647091     116.696145  505.757033
#
#                   NU_NOTA_CH  NU_NOTA_LC
# CO_MUNICIPIO_ESC
# 1100015.0         508.945000  493.100000
# 1100023.0         502.671769  488.942517
# 1100031.0         499.300000  448.800000
# 1100049.0         508.772800  495.864800
# 1100056.0         492.134375  474.131250
# ...                      ...         ...
# 5222005.0         488.486486  474.918919
# 5222054.0         468.135714  457.967857
# 5222203.0         445.263636  425.809091
# 5222302.0         413.277778  423.616667
# 5300108.0         536.395896  523.912319
#
# [5477 rows x 10 columns]

# %%
geo_municipios = pd.read_csv('municipios_geo.csv', encoding='ISO_8859_1')

# %%
geo_municipios.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
enem_geo=pd.merge(df, geo_municipios, how='left', left_on=['CO_MUNICIPIO_ESC'], right_on=['codigo_ibge'])

# %%
enem_geo.head().sort_values(by = 'NU_NOTA_REDACAO', ascending=False)
# Out:
#    NU_NOTA_MT  NU_NOTA_REDACAO  NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  \
# 0  546.662500       649.000000     118.500000     144.500000     117.500000
# 3  533.458933       622.506667     117.013333     140.906667     115.520000
# 1  518.904422       600.000000     114.285714     135.170068     112.176871
# 4  480.696875       598.125000     115.000000     134.375000     115.000000
# 2  522.883333       470.000000     106.666667     116.666667      86.666667
#
#    NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 0     141.500000     127.000000  499.987500  508.945000  493.100000
# 3     130.026667     119.040000  489.744000  508.772800  495.864800
# 1     125.238095     113.129252  475.539456  502.671769  488.942517
# 4     125.625000     108.125000  479.268750  492.134375  474.131250
# 2      93.333333      66.666667  477.266667  499.300000  448.800000
#
#    codigo_ibge                   nome  latitude  longitude  capital  codigo_uf
# 0      1100015  Alta Floresta D'Oeste -11.92830   -61.9953        0         11
# 3      1100049                 Cacoal -11.43430   -61.4562        0         11
# 1      1100023              Ariquemes  -9.90571   -63.0325        0         11
# 4      1100056             Cerejeiras -13.18700   -60.8168        0         11
# 2      1100031                 Cabixi -13.49450   -60.5520        0         11

# %%
enem_geo.plot.scatter(y = 'latitude', x = 'longitude', 
                      c=enem_geo['NU_NOTA_REDACAO'], 
                      cmap='RdYlGn', 
                      figsize=(12,8), 
                      title = 'Nota de redação do Enem por municípios' )
# Out:
# <AxesSubplot:title={'center':'Nota de redação do Enem por municípios'}, xlabel='longitude', ylabel='latitude'>

# %%
fig, ax = plt.subplots(2,2, figsize=(16, 14)) #2,2 é o tamanho de cada subplot

enem_geo.plot.scatter(y = 'latitude', x = 'longitude', 
                      c=enem_geo['NU_NOTA_MT'], 
                      cmap='RdYlGn',  
                      title = 'Nota em matemática',
                      ax = ax [0,0] ) #esta linha indica a posição da variavel na figura

enem_geo.plot.scatter(y = 'latitude', x = 'longitude', 
                      c=enem_geo['NU_NOTA_CN'], 
                      cmap='RdYlGn',  
                      title = 'Nota em Ciências da natureza',
                      ax = ax [0,1] ) 

enem_geo.plot.scatter(y = 'latitude', x = 'longitude', 
                      c=enem_geo['NU_NOTA_CH'], 
                      cmap='RdYlGn',  
                      title = 'Nota em Ciências humanas',
                      ax = ax [1,0] ) 

enem_geo.plot.scatter(y = 'latitude', x = 'longitude', 
                      c=enem_geo['NU_NOTA_LC'], 
                      cmap='RdYlGn', 
                      title = 'Nota em Linguagens e códigos',
                      ax = ax [1,1] )
# Out:
# <AxesSubplot:title={'center':'Nota em Linguagens e códigos'}, xlabel='longitude', ylabel='latitude'>
